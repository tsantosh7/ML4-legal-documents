# %%
from docx import Document
import pandas as pd
import os
from tqdm import tqdm

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# %%
import os

# Base directory
base_dir = '../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/'

# Lists to hold .docx file paths
year_folder_files = []
subfolder_files = []

# Walking through the directory
for dirpath, dirnames, filenames in os.walk(base_dir):
    # Calculate depth of current directory
    depth = len(os.path.normpath(os.path.relpath(dirpath, base_dir)).split(os.path.sep))

    # Filtering and adding .docx files to the appropriate list
    for file in filenames:
        if file.endswith('.docx'):
            full_path = os.path.join(dirpath, file)
            if depth == 1:
                year_folder_files.append(full_path)
            elif depth > 1:
                subfolder_files.append(full_path)

# %%
# Printing the lists of .docx files
print("Files in Year Folders:")
for file in year_folder_files:
    print(file)
# Out:
# Files in Year Folders:
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2016/2016 MIXED and single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2016/2016 single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/2019 Appeal Court Judgments - Single cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/2019 Appeal Court Judgments - MIXED and single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/Criminal Appeal Court Cases for 2018 - MIXED and Single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/Criminal Appeal Court Cases for 2018 - Single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2011/2011 Single defendant case.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2017/2017 MIXED and single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2017/2017 single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2015/2015 MIXED and single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2015/2015 single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/Appeal Court Judgment 2010 - keywords, single defendant cases.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/Appeal Court Judgment 2010 - keywords.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/Appeal Court Judgment 2010 - keywords, single and multiple cases.docx

# %%
print("\nFiles in Subfolders:")
for file in subfolder_files:
    print(file)
# Out:
# Files in Subfolders:
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2016/JULY 2016/Oliver JULY 2016.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2016/JAN 2016/Ogden JAN 2016.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Beale MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Diamond MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Harper MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Ayres MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Baines MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MARCH 2019/Faltec MARCH 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Dixon JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/R Brown JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/PR  JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Turner  JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Aslam JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/L  JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Fox JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Downton JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JULY 2019/Seddon JULY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/SEPT 2019/Aziz SEPT 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/NOV 2019/McNulty NOV 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/NOV 2019/Townsend NOV 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/NOV 2019/Rashid NOV 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/NOV 2019/Broadhurst NOV 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/FEB 2019/Challen FEB 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/FEB 2019/SA and Others FEB 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/FEB 2019/Dobson FEB 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Graham JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Bexley JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Shepherd JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Assaf and others JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Woodward and others JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JUNE 2019/Sargeant JUNE 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/Gorman DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/Choudhuri DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/Donovan and Woolcock DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/PS DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/Abdurahman DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/DEC 2019/Islam DEC 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MAY 2019/Welsby MAY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MAY 2019/Allen MAY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MAY 2019/Wilkinson MAY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MAY 2019/Deiss-Dias MAY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/MAY 2019/Chall MAY 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/APRIL 2019/Rendell APRIL 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/APRIL 2019/Bridge APRIL 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/APRIL 2019/Imran Hussain APRIL 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/JAN 2019/Alam JAN 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/OCT 2019/Pringle OCT 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2019/OCT 2019/Yuel OCT 2019.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JAN 2018/B, R JAN 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JAN 2018/Sartain JAN 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/AUG 2018/Cyprian AUG 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/SEPT 2018/Gray SEPT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/SEPT 2018/Monington SEPT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/SEPT 2018/Thompson SEPT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/Coles FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/James FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/BECH FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/SM FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/AS FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/FEB 2018/Townshend FEB 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/NOV 2018/Aziz NOV 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/NOV 2018/E.R. NOV 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/NOV 2018/Khan NOV 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JUNE 2018/Omotoso JUNE 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JUNE 2018/Cooper JUNE 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/DEC 2018/Jones DEC 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Turnstill JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Edgar JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Mayer JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Kelly JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Doyle JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/Gordon JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/JULY 2018/GS JULY 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/APRIL 2018/Lewis APRIL 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/APRIL 2018/Nichols APRIL 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/APRIL 2018/Tesfazgi APRIL 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/APRIL 2018/Rana APRIL 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Harvey MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Langley MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Wallace MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Edwards MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Hinds MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Rai MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Davies MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/LG MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Pabron MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Wilson MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Mathieson MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Knapper MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/McCotter MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/McDonald MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Hassan MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/RK MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Mamaliga MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/MARCH 2018/Lincoln MARCH 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/Goodwin OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/Capitao OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/Hodge OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/Simmons OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/McMeekin OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2018/OCT 2018/Fender OCT 2018.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2011/MAY 2011/Smith MAY 2011.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2017/DEC 2017/Parsons DEC 2017.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2017/DEC 2017/Kay DEC 2017.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2017/DEC 2017/Morgan DEC 2017.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2015/DEC 2015/R & Ors DEC 2015.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2015/FEB 2015/Boardman FEB 2015.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/OCT 2010/Laxton OCT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/OCT 2010/Wenton OCT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/OCT 2010/Yam OCT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/OCT 2010/Inglis OCT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/OCT 2010/SB OCT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/SEPT 2010/Harding SEPT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/SEPT 2010/Simpson SEPT 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JUNE 2010/Oladapo JUNE 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JUNE 2010/Henderson JUNE 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JUNE 2010/Hussein - Shabran JUNE 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JUNE 2010/Butler JUNE 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/Akinrele DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/O'Shea DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/Barron DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/Pluck DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/Burridge DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/DEC 2010/Ahmed DEC 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/NOV 2010/CR NOV 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/NOV 2010/Joesph NOV 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/NOV 2010/PR NOV 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/FEB 2010/Khatun FEB 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/FEB 2010/RCPO-C FEB 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JAN 2010/JABAR-JAN 2010 FINAL.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JAN 2010/MACKAY-JAN 2010 FINAL.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JAN 2010/SABI-JAN 2010 FINAL.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JAN 2010/BELL-JAN 2010 FINAL.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JAN 2010/SB-JAN 2010 FINAL.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MAY 2010/C, R MAY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MAY 2010/Kenyon MAY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MAY 2010/Miller MAY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MAY 2010/Connolly MAY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MAY 2010/Baballa MAY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MARCH 2010/Broughton MARCH 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MARCH 2010/Naish MARCH 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MARCH 2010/Osborne MARCH 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/MARCH 2010/Weller MARCH 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JULY 2010/Stewart JULY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JULY 2010/Watts JULY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JULY 2010/Weston JULY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/JULY 2010/Bagot JULY 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/APRIL 2010/Robinson and Jordan APRIL 2010.docx
# ../Appeal Court Judgments/APPEAL COURT JUDGMENTS 280520/2010/APRIL 2010/Okuwa APRIL 2010.docx

# %%
for each_year in tqdm(year_folder_files):
    extracted_list = []
    document = Document(each_year)
    for para in document.paragraphs:
        para_list = [x for x in para.text.split('\t') if x]
        if len(para_list)==3:
            extracted_list.append(para_list)
    
df = pd.DataFrame(extracted_list, columns = ['Case', 'Keywords', 'Outcome'])
# Out:
# 100%|███████████████████████████████████████████| 14/14 [00:00<00:00, 51.99it/s]

# %%
df
# Out:
#                                                  Case  \
# 0     Bell, R. v [2010] EWCA Crim 3 (19 January 2010)
# 1   Jabar, R. v [2010] EWCA Crim 130 (26 January 2...
# 22               Forensic, Expert, DNA  Dismissed
# 23                       Forensic, DNA  Dismissed
# 24               Forensic, Expert, DNA    Granted
# 25                         Fingerprint    Granted
# 26                    Forensic, Expert    Refused
# 27               Forensic, Expert, DNA    Granted
# 28                    Forensic, Expert  Dismissed
# 29                              Expert  Dismissed
# 30                    Forensic, Expert  Dismissed
# 31                              Expert  Dismissed
# 32               Forensic, Expert, DNA  Dismissed
# 33                    Forensic, Expert  Dismissed
# 34  Forensic, Expert, DNA, Fingerprint  Dismissed

# %%
keywords_series = df['Keywords'].str.split(', ').apply(pd.Series).stack()
keywords_count = keywords_series.value_counts()

# Outcome count
outcome_count = df['Outcome'].value_counts()

# Plotting the data
plt.figure(figsize=(12, 6))

# Bar chart for Keywords
plt.subplot(1, 2, 1)
sns.barplot(x=keywords_count.values, y=keywords_count.index)
plt.title('Frequency of Keywords')
plt.xlabel('Count')
plt.ylabel('Keywords')

# Bar chart for Outcomes
plt.subplot(1, 2, 2)
sns.barplot(x=outcome_count.values, y=outcome_count.index)
plt.title('Frequency of Outcomes')
plt.xlabel('Count')
plt.ylabel('Outcomes')

plt.tight_layout()
plt.show()

# %%
# Calculating the percentages for keywords and outcomes

# Total counts for keywords and outcomes
total_keywords = keywords_count.sum()
total_outcomes = outcome_count.sum()

# Calculating percentages
keywords_percentage = (keywords_count / total_keywords) * 100
outcomes_percentage = (outcome_count / total_outcomes) * 100

# Creating DataFrames for better display
keywords_percentage_df = keywords_percentage.reset_index()
keywords_percentage_df.columns = ['Keyword', 'Percentage']

outcomes_percentage_df = outcomes_percentage.reset_index()
outcomes_percentage_df.columns = ['Outcome', 'Percentage']

# %%
keywords_percentage_df
# Out:
#        Keyword  Percentage
# 0     Forensic   34.285714
# 1       Expert   32.857143
# 2          DNA   24.285714
# 3       expert    4.285714
# 4  Fingerprint    4.285714

# %%
outcomes_percentage_df
# Out:
#      Outcome  Percentage
# 0  Dismissed   62.857143
# 1    Granted   25.714286
# 2    Refused    8.571429
# 3    Retrial    2.857143

# %%
import re

def has_serial_number(cell_text):
    return bool(re.match(r'^\d+\.', cell_text))

document = Document(subfolder_files[10])

# %%
tables = []
for index,table in enumerate(document.tables):
    df_table = [['' for i in range(len(table.columns))] for j in range(len(table.rows))]
    for i, row in enumerate(table.rows):
        for j, cell in enumerate(row.cells):
            df_table[i][j] = cell.text
            
# Filter and add rows with serial numbers
for row in df_table:
    if row and has_serial_number(row[0]):
        tables.append(row)
tables.append(df_table[-1])

# %%
len(tables)
# Out:
# 117

# %%
filter(document.paragraphs[13].text.split('\t'),'None')

# %%
import os
import pandas as pd
from docx import Document

# Use the previously obtained list of docx files
files = docx_files

# Generate a unique name for each file for the corresponding Excel files
names = [os.path.splitext(os.path.basename(file))[0] for file in files]

for file, name in zip(files, names):
    document = Document(file)
    for index, table in enumerate(document.tables):
        df = pd.DataFrame(columns=range(len(table.columns)), index=range(len(table.rows)))
        for i, row in enumerate(table.rows):
            for j, cell in enumerate(row.cells):
                df.iloc[i, j] = cell.text
#         excel_file_name = f"{name}_{index}.xlsx"
#         df.to_excel(excel_file_name, index=False)
                break
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 14
#      12 document = Document(file)
#      13 for index, table in enumerate(document.tables):
# ---> 14     df = pd.DataFrame(columns=range(len(table.columns)), index=range(len(table.rows)))
#      15     for i, row in enumerate(table.rows):
#      16         for j, cell in enumerate(row.cells):
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/frame.py:807, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     798             mgr = ndarray_to_mgr(
#     799                 data,
#     800                 index,
#    (...)
#     804                 typ=manager,
#     805             )
#     806     else:
# --> 807         mgr = dict_to_mgr(
#     808             {},
#     809             index,
#     810             columns if columns is not None else default_index(0),
#     811             dtype=dtype,
#     812             typ=manager,
#     813         )
#     814 # For data is scalar
#     815 else:
#     816     if index is None or columns is None:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/internals/construction.py:431, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     428 if columns is not None:
#     429     from pandas.core.series import Series
# --> 431     arrays = Series(data, index=columns, dtype=object)
#     432     missing = arrays.isna()
#     433     if index is None:
#     434         # GH10856
#     435         # raise ValueError if only scalars in dict
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/series.py:472, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     470         data = data._mgr
#     471 elif is_dict_like(data):
# --> 472     data, index = self._init_dict(data, index, dtype)
#     473     dtype = None
#     474     copy = False
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/series.py:565, in Series._init_dict(self, data, index, dtype)
#     562     keys, values = default_index(0), []
#     564 # Input is now list-like, so rely on "standard" construction:
# --> 565 s = Series(values, index=keys, dtype=dtype)
#     567 # Now we just make sure the order is respected, if any
#     568 if data and index is not None:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/construction.py:541, in sanitize_array(data, index, dtype, copy, allow_2d)
#     539     if index is None:
#     540         raise ValueError("index must be specified when data is not list-like")
# --> 541     data = construct_1d_arraylike_from_scalar(data, len(index), dtype)
#     542     return data
#     544 elif isinstance(data, ABCExtensionArray):
#     545     # it is already ensured above this is not a PandasArray
#     546     # Until GH#49309 is fixed this check needs to come before the
#     547     #  ExtensionDtype check
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1555, in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1552 elif dtype.kind in ["M", "m"]:
#    1553     value = _maybe_box_and_unbox_datetimelike(value, dtype)
# -> 1555 subarr = np.empty(length, dtype=dtype)
#    1556 if length:
#    1557     # GH 47391: numpy > 1.24 will raise filling np.nan into int dtypes
#    1558     subarr.fill(value)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                                      0    1
# 0                               \nSAMPLE DESCRIPTION\n  NaN
# 1                                              1. Case  NaN
# 2                            2. Date of appeal hearing  NaN
# 3                 3. Date of original trial/conviction  NaN
# 4                            4. Keywords found in case  NaN
# ..                                                 ...  ...
# 127  113. For Digital evidence, did the investigato...  NaN
# 128  114. For Digital evidence, were the investigat...  NaN
# 129  115. Were there any Co-defendants? 115b. If ye...  NaN
# 130  116. Where the case involved co-defendant/s, w...  NaN
# 131  NOTES – PLEASE WRITE ANYTHING THAT YOU THINK I...  NaN
#
# [132 rows x 2 columns]

# %%
df.to_csv('test.csv', sep='\t')
