# %%
# !pip install pip install python-docx
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
for file,name in zip(files,list1):
    document = Document(file)
    tables = []
    for index,table in enumerate(document.tables):
        df = [['' for i in range(len(table.columns))] for j in range(len(table.rows))]
        for i, row in enumerate(table.rows):
            for j, cell in enumerate(row.cells):
                df[i][j] = cell.text
            pd.DataFrame(df).to_excel(name+".xlsx")

# %%
list1=['2012',
'2013',
'2014',
'2015 MIXED and single defendant cases',
'2015 single defendant cases',
'2016 MIXED and single defendant cases',
'2016 single defendant cases',
'2017 MIXED and single defendant cases',
'2017 single defendant cases',
'Abdurahman DEC 2019',
'Ahmed DEC 2010',
'Akinrele DEC 2010',
'Alam JAN 2019',
'Allen MAY 2019',
'AS FEB 2018',
'Aslam JULY 2019',
'Assaf and others JUNE 2019',
'Ayres MARCH 2019',
'Aziz NOV 2018',
'Aziz SEPT 2019',
'B, R JAN 2018',
'Baballa MAY 2010',
'Bagot JULY 2010',
'Baines MARCH 2019',
'Barron DEC 2010',
'Beale MARCH 2019',
'BECH FEB 2018',
'BELL-JAN 2010 FINAL',
'Bexley JUNE 2019',
'Boardman FEB 2015',
'Bridge APRIL 2019',
'Broadhurst NOV 2019',
'Broughton MARCH 2010',
'Burridge DEC 2010',
'Butler JUNE 2010',
'C, R MAY 2010',
'Capitao OCT 2018',
'Chall MAY 2019',
'Challen FEB 2019',
'Choudhuri DEC 2019',
'Coles FEB 2018',
'Connolly MAY 2010',
'Cooper JUNE 2018',
'CR NOV 2010',
'Cyprian AUG 2018',
'Davies MARCH 2018',
'Deiss-Dias MAY 2019',
'Diamond MARCH 2019',
'Dixon JULY 2019',
'Dobson FEB 2019',
'Donovan and Woolcock DEC 2019',
'Downton JULY 2019',
'Doyle JULY 2018',
'E.R. NOV 2018',
'Edgar JULY 2018',
'Edwards MARCH 2018',
'Faltec MARCH 2019',
'Fender OCT 2018',
'Fox JULY 2019',
'Goodwin OCT 2018',
'Gordon JULY 2018',
'Gorman DEC 2019',
'Graham JUNE 2019',
'Gray SEPT 2018',
'GS JULY 2018',
'Harding SEPT 2010',
'Harper MARCH 2019',
'Harvey MARCH 2018',
'Hassan MARCH 2018',
'Henderson JUNE 2010',
'Hinds MARCH 2018',
'Hodge OCT 2018',
'Hussein - Shabran JUNE 2010',
'Imran Hussain APRIL 2019',
'Inglis OCT 2010',
'Islam DEC 2019',
'JABAR-JAN 2010 FINAL',
'James FEB 2018',
'Joesph NOV 2010',
'Jones DEC 2018',
'Kay DEC 2017',
'Kelly JULY 2018',
'Kenyon MAY 2010',
'Khan NOV 2018',
'Khatun FEB 2010',
'Knapper MARCH 2018',
'L  JULY 2019',
'Langley MARCH 2018',
'Laxton OCT 2010',
'Lewis APRIL 2018',
'LG MARCH 2018',
'Lincoln MARCH 2018',
'MACKAY-JAN 2010 FINAL',
'Mamaliga MARCH 2018',
'Mathieson MARCH 2018',
'Mayer JULY 2018',
'McCotter MARCH 2018',
'McDonald MARCH 2018',
'McMeekin OCT 2018',
'McNulty NOV 2019',
'Miller MAY 2010',
'Monington SEPT 2018',
'Morgan DEC 2017',
'Naish MARCH 2010',
'Nichols APRIL 2018',
'O Shea DEC 2010',
'Ogden JAN 2016',
'Okuwa APRIL 2010',
'Oladapo JUNE 2010',
'Oliver JULY 2016',
'Omotoso JUNE 2018',
'Osborne MARCH 2010',
'Pabron MARCH 2018',
'Parsons DEC 2017',
'Pluck DEC 2010',
'PR  JULY 2019',
'PR NOV 2010',
'Pringle OCT 2019',
'PS DEC 2019',
'R & Ors DEC 2015',
'R Brown JULY 2019',
'Rai MARCH 2018',
'Rana APRIL 2018',
'Rashid NOV 2019',
'RCPO-C FEB 2010',
'Rendell APRIL 2019',
'RK MARCH 2018',
'Robinson and Jordan APRIL 2010',
'SA and Others FEB 2019',
'SABI-JAN 2010 FINAL',
'Sargeant JUNE 2019',
'Sartain JAN 2018',
'SB OCT 2010',
'SB-JAN 2010 FINAL'
'Seddon JULY 2019',
'Shepherd JUNE 2019',
'Simmons OCT 2018',
'Simpson SEPT 2010',
'SM FEB 2018',
'Smith MAY 2011',
'Stewart JULY 2010',
'Tesfazgi APRIL 2018',
'Thompson SEPT 2018',
'Townsend NOV 2019',
'Townshend FEB 2018',
'Turner  JULY 2019',
'Turnstill JULY 2018',
'Wallace MARCH 2018',
'Watts JULY 2010',
'Weller MARCH 2010',
'Welsby MAY 2019',
'Wenton OCT 2010',
'Weston JULY 2010',
'Wilkinson MAY 2019',
'Wilson MARCH 2018',
'Woodward and others JUNE 2019',
'Yam OCT 2010',
'Yuel OCT 2019']
